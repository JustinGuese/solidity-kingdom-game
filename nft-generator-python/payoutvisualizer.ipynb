# %%
import matplotlib.pyplot as plt

# %%
# i want a function that returns payout value from 1 - 10000 favoring top positions

# %%
sum = 0
def formula(x):
    return (-(5/10)*x + 5000 ) / 50000 / 500

for i in range(10000):
    crnt = formula(i) 
    sum += crnt
    print(i, crnt)
print(sum)
# Out:
# 0 0.0002
# 1 0.00019998
# 2 0.00019996
# 3 0.00019994
# 4 0.00019992
# 5 0.0001999
# 6 0.00019988
# 7 0.00019986
# 8 0.00019983999999999998
# 9 0.00019982
# 10 0.0001998
# 11 0.00019978000000000002
# 12 0.00019976
# 13 0.00019974
# 14 0.00019972000000000002
# 15 0.00019969999999999998
# 16 0.00019967999999999999
# 17 0.00019966
# 18 0.00019964
# 19 0.00019962
# 20 0.0001996
# 21 0.00019958
# 22 0.00019956
# 23 0.00019954
# 24 0.00019952000000000001
# 25 0.0001995
# 26 0.00019947999999999998
# 27 0.00019946
# 28 0.00019944
# 29 0.00019941999999999998
# 30 0.0001994
# 31 0.00019938
# 32 0.00019936000000000002
# 33 0.00019934
# 34 0.00019932
# 35 0.0001993
# 36 0.00019928
# 37 0.00019925999999999999
# 38 0.00019924
# 39 0.00019922
# 40 0.0001992
# 41 0.00019918
# 42 0.00019916
# 43 0.00019914000000000002
# 44 0.00019912
# 45 0.0001991
# 46 0.00019908
# 47 0.00019905999999999998
# 48 0.00019904
# 49 0.00019902
# 50 0.000199
# 51 0.00019898
# 52 0.00019896
# 53 0.00019894000000000002
# ...
